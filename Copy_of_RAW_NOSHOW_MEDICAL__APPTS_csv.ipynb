# %% [markdown]
# <a href="https://colab.research.google.com/github/Datadog-995/Medical-Appointment-NoShows-Portfolio/blob/main/Copy_of_RAW_NOSHOW_MEDICAL__APPTS_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("joniarroba/noshowappointments")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.40M/2.40M [00:00<00:00, 133MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/joniarroba/noshowappointments/versions/5

# %%
import pandas as pd
import os

# Find the CSV file in the downloaded directory
csv_filename = [f for f in os.listdir(path) if f.endswith('.csv')][0]
full_file_path = os.path.join(path, csv_filename)

# Load the dataset and display the first 25 rows
df = pd.read_csv(full_file_path)
df.head(25)
# Out:
#        PatientId  AppointmentID Gender          ScheduledDay  \
# 0   2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1   5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2   4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3   8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4   8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# 5   9.598513e+13        5626772      F  2016-04-27T08:36:51Z
# 6   7.336882e+14        5630279      F  2016-04-27T15:05:12Z
# 7   3.449833e+12        5630575      F  2016-04-27T15:39:58Z
# 8   5.639473e+13        5638447      F  2016-04-29T08:02:16Z
# 9   7.812456e+13        5629123      F  2016-04-27T12:48:25Z
# 10  7.345362e+14        5630213      F  2016-04-27T14:58:11Z
# 11  7.542951e+12        5620163      M  2016-04-26T08:44:12Z
# 12  5.666548e+14        5634718      F  2016-04-28T11:33:51Z
# 13  9.113946e+14        5636249      M  2016-04-28T14:52:07Z
# ...
